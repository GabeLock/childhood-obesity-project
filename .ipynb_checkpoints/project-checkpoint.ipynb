# %% [markdown]
# > COLETA, CARREGAMENTO e ANALISE EXPLORATÓRIA DOS DADOS (EDA)

# %%
import os

# Listar arquivos no diretório atual
print(os.listdir('C:/Users/Administrator/Documents/Programação/Projetos/childhood-obesity-project'))
# Out:
# ['.ipynb_checkpoints', 'child_ob.ipynb', 'child_ob_gender.csv', 'env', 'obesity_child_age.csv', 'project.ipynb']

# %%
import pandas as pd

# Carregar os datasets
df_gender = pd.read_csv('C:/Users/Administrator/Documents/Programação/Projetos/childhood-obesity-project/child_ob_gender.csv')
df_age = pd.read_csv('C:/Users/Administrator/Documents/Programação/Projetos/childhood-obesity-project/obesity_child_age.csv')

# %%
# Visualizar as primeiras linhas do dataset
print (df_gender.head())
print (df_age.head())
# Out:
#    index         Time Gender  PercentOW  PercentOB
# 0      0  [1971,1974]      F       10.1        5.1
# 1      1  [1976,1980]      F        9.0        5.6
# 2      2  [1988,1994]      F       13.4        9.8
# 3      3  [1999,2000]      F       13.4       13.8
# 4      4  [2001,2002]      F       15.0       14.3
#    index         Time    Age Gender  PercentObese   SE
# 0      0  [1971,1974]  [2,5]    All           5.0 -0.6
# 1      1  [1976,1980]  [2,5]    All           5.0 -0.6
# 2      2  [1988,1994]  [2,5]    All           7.2 -0.7
# 3      3  [1999,2000]  [2,5]    All          10.3 -1.7
# 4      4  [2001,2002]  [2,5]    All          10.6 -1.8

# %%
# Informações dos dados
print(df_gender.info())
print(df_age.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      33 non-null     int64
#  1   Time       33 non-null     object
#  2   Gender     33 non-null     object
#  3   PercentOW  33 non-null     float64
#  4   PercentOB  33 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         99 non-null     int64
#  1   Time          99 non-null     object
#  2   Age           99 non-null     object
#  3   Gender        99 non-null     object
#  4   PercentObese  99 non-null     float64
#  5   SE            99 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB
# None

# %%
# Estatísticas descritivas
print(df_gender.describe())
print(df_age.describe())
# Out:
#           index  PercentOW  PercentOB
# count  33.00000  33.000000  33.000000
# mean   16.00000  13.924242  13.654545
# std     9.66954   2.244581   4.508609
# min     0.00000   9.000000   5.100000
# 25%     8.00000  13.400000  10.200000
# 50%    16.00000  14.600000  15.400000
# 75%    24.00000  15.400000  16.900000
# max    32.00000  16.600000  18.600000
#            index  PercentObese         SE
# count  99.000000     99.000000  99.000000
# mean   49.000000     12.966667  -1.510101
# std    28.722813      5.188665   0.601104
# min     0.000000      3.600000  -3.200000
# 25%    24.500000      9.350000  -2.000000
# 50%    49.000000     14.100000  -1.600000
# 75%    73.500000     17.550000  -1.000000
# max    98.000000     21.400000  -0.500000

# %%
# Identificar valores ausentes
print(df_gender.isnull().sum())
print(df_age.isnull().sum())
# Out:
# index        0
# Time         0
# Gender       0
# PercentOW    0
# PercentOB    0
# dtype: int64
# index           0
# Time            0
# Age             0
# Gender          0
# PercentObese    0
# SE              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogramas
df_gender.hist(bins=30, figsize=(10, 8))
plt.suptitle('Distribuição dos Dados - Gender')
plt.show()

df_age.hist(bins=30, figsize=(10, 8))
plt.suptitle('Distribuição dos Dados - Age')
plt.show()

# Gráficos de dispersão
sns.pairplot(df_gender)
plt.suptitle('Correlação dos Dados - Gender')
plt.show()

sns.pairplot(df_age)
plt.suptitle('Correlação dos Dados - Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecionar apenas colunas numéricas
numeric_df_age = df_age.select_dtypes(include=['float64', 'int64'])

# Calcular a matriz de correlação
correlation_matrix_age = numeric_df_age.corr()

# Visualizar a matriz de correlação usando um heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_age, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlação - Dataset Age')
plt.show()

# %% [raw]
# Interpretação da Matriz de Correlação
#
# Após executar o código, você verá um gráfico de calor (heatmap) que visualiza a matriz de correlação. Aqui está um exemplo de como interpretar os resultados:
#
# Correlação Próxima de Zero:
# Valores próximos de zero indicam pouca ou nenhuma correlação.
# Se PercentObese e SE têm um coeficiente de correlação próximo de zero, isso confirma que não há uma relação linear significativa entre eles.
# Explicação Visual
# A visualização da matriz de correlação nos ajuda a entender as relações entre variáveis de maneira simples e clara. Aqui está uma ilustração de como interpretar um heatmap de correlação:
#
# Exemplo de Heatmap
# index	                PercentObese	SE
# index	       1	    0.02	        0.01
# PercentObese   0.02	    1	            0.05
# SE	           0.01	    0.05	        1
#
# Valor 1 na diagonal: Cada variável tem uma correlação perfeita consigo mesma.
# Valores próximos de 0.02 e 0.05: Indicam uma correlação muito baixa, confirmando a ausência de uma relação significativa.
#
# Conclusão
#
# index vs PercentObese e SE: O índice não tem valor analítico além de ser um identificador de linha, então não esperamos ver correlações.
# PercentObese vs SE: A ausência de correlação visível e os coeficientes de correlação próximos de zero indicam que a variabilidade nos percentuais de obesidade (SE) não está relacionada diretamente aos próprios percentuais de obesidade.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Carregar o dataset
df_gender = pd.read_csv('C:/Users/Administrator/Documents/Programação/Projetos/childhood-obesity-project/child_ob_gender.csv')

# Calcular a correlação de Pearson entre PercentOW e PercentOB
correlation, p_value = pearsonr(df_gender['PercentOW'], df_gender['PercentOB'])

# Exibir a correlação e o valor p
print(f'Coeficiente de Correlação de Pearson: {correlation}')
print(f'Valor p: {p_value}')

# Plotar gráfico de dispersão com linha de tendência
sns.regplot(x='PercentOW', y='PercentOB', data=df_gender)
plt.title('Relação entre PercentOW e PercentOB')
plt.xlabel('Percentual de Sobrepeso (PercentOW)')
plt.ylabel('Percentual de Obesidade (PercentOB)')
plt.show()
# Out:
# Coeficiente de Correlação de Pearson: 0.9330169125133005
# Valor p: 2.6305300561589737e-15

# %% [raw]
# Interpretação dos Resultados
# Coeficiente de Correlação de Pearson:
#
# Um valor positivo alto indica uma forte correlação positiva entre PercentOW e PercentOB. Isso significa que, conforme o percentual de sobrepeso aumenta, o percentual de obesidade também tende a aumentar.
# Valor p:
#
# Um valor p baixo (< 0.05) indica que a correlação observada é estatisticamente significativa, ou seja, é improvável que a correlação observada tenha ocorrido por acaso.
# Gráfico de Dispersão:
#
# A linha de tendência no gráfico de dispersão fornece uma visualização clara da relação linear entre PercentOW e PercentOB.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar o dataset
df_gender = pd.read_csv('C:/Users/Administrator/Documents/Programação/Projetos/childhood-obesity-project/child_ob_gender.csv')

# Selecionar apenas colunas numéricas
numeric_df_gender = df_gender.select_dtypes(include=['float64', 'int64'])

# Calcular a matriz de correlação
correlation_matrix_gender = numeric_df_gender.corr()

# Visualizar a matriz de correlação usando um heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_gender, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlação - Dataset Gender')
plt.show()

# %% [raw]
# Conclusão
# Correlação entre PercentOW e PercentOB: Se a célula no heatmap mostra um valor de correlação alto, isso confirma uma forte correlação positiva entre PercentOW e PercentOB.
# Visualização das Relações: O heatmap fornece uma visão clara e visual das correlações entre as variáveis numéricas.

# %% [raw]
# Para aprofundar a análise e enriquecer o projeto, seria extremamente valioso obter dados adicionais sobre as crianças estudadas, como localidade, estrutura familiar, renda familiar, escolaridade dos pais e estilo de vida dos pais. Esses dados podem fornecer insights mais profundos sobre os fatores que contribuem para o sobrepeso e a obesidade infantil, permitindo uma análise mais holística e precisa.
#
# A coleta e integração de dados adicionais sobre demografia, socioeconomia e estilo de vida são essenciais para uma compreensão mais completa dos fatores que influenciam o sobrepeso e a obesidade infantil. Com esses dados, podemos desenvolver intervenções mais eficazes e personalizadas. Este avanço pode ser proposto como um projeto futuro, trazendo benefícios significativos para a saúde pública e o bem-estar das crianças.
